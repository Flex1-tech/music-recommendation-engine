# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('base_musique_complete_cleaned.csv')
# conversion to numpy
n_df = df.to_numpy()
n_df
# Out:
# array([['100 Blaze feat. Koba LaD - Binks.mp3',
#         '100 Blaze,  feat. , Koba LaD', 'Binks', ..., nan, nan, nan],
#        ['13 Block feat. Niska - Tieks.m4a', '13 Block feat. Niska',
#         'Tieks', ..., 202.0, 11.0, 7.0],
#        ['1da Banton - No Wahala.mp3', '1da Banton', 'No Wahala', ...,
#         162.0, 897694.0, 132997.0],
#        ...,
#        ['Zlatan - Ale Yi.mp3', 'Zlatan', 'Ale Yi', ..., 0.0, 8313.0,
#         1428.0],
#        ['Zola feat. Tiakola - TOUTE LA JOURNÉE.mp3',
#         'Zola,  feat. , Tiakola', 'TOUTE LA JOURNÉE', ..., 0.0, 709.0,
#         83.0],
#        ['近藤晃央 - ブラックナイトタウン.mp3', '近藤晃央', 'ブラックナイトタウン', ..., 0.0, 7552.0,
#         467.0]], shape=(748, 28), dtype=object)
